# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import seaborn as sns
df=pd.read_csv("C:\\Users\\admin\\Downloads\\50_Startups.csv")

# %%
df =df.rename(columns={"R&D Spend":"RnD","Marketing Spend": "Marketing_Spend"})
df
# Out:
#           RnD  Administration  Marketing_Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df1=df.drop(["State"],axis=1)
df1
# Out:
#           RnD  Administration  Marketing_Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  101913.08       110594.11        229160.95  146121.95
# 11  100671.96        91790.61        249744.55  144259.40
# 12   93863.75       127320.38        249839.44  141585.52
# 13   91992.39       135495.07        252664.93  134307.35
# 14  119943.24       156547.42        256512.92  132602.65
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RnD              50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing_Spend  50 non-null     float64
#  3   Profit           50 non-null     float64
# dtypes: float64(4)
# memory usage: 1.7 KB

# %%
df1.describe()
# Out:
#                  RnD  Administration  Marketing_Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df1.isna().sum()
# Out:
# RnD                0
# Administration     0
# Marketing_Spend    0
# Profit             0
# dtype: int64

# %%
df1.corr()
# Out:
#                       RnD  Administration  Marketing_Spend    Profit
# RnD              1.000000        0.241955         0.724248  0.972900
# Administration   0.241955        1.000000        -0.032154  0.200717
# Marketing_Spend  0.724248       -0.032154         1.000000  0.747766
# Profit           0.972900        0.200717         0.747766  1.000000

# %%
sns.set_style(style='darkgrid')
sns.pairplot(df1)

# %% [markdown]
# # Preparing a model

# %%
import statsmodels.formula.api as smf
model=smf.ols('Profit~RnD+Administration+Marketing_Spend',data=df1).fit()

# %%
model.params
# Out:
# Intercept          50122.192990
# RnD                    0.805715
# Administration        -0.026816
# Marketing_Spend        0.027228
# dtype: float64

# %%
print(model.tvalues, '\n',model.pvalues)
# Out:
# Intercept           7.626218
# RnD                17.846374
# Administration     -0.525507
# Marketing_Spend     1.655077
# dtype: float64
#  Intercept          1.057379e-09
# RnD                2.634968e-22
# Administration     6.017551e-01
# Marketing_Spend    1.047168e-01
# dtype: float64

# %%
(model.rsquared,model.rsquared_adj)
# Out:
# (0.9507459940683246, 0.9475337762901719)

# %% [markdown]
# # Calculating VIF

# %%
RnD=smf.ols('RnD~Administration+Marketing_Spend',data=df1).fit().rsquared
RnD=1/(1-RnD)

Administration=smf.ols('Administration~RnD+Marketing_Spend',data=df1).fit().rsquared
Administration=1/(1-Administration)

Marketing_Spend=smf.ols('Marketing_Spend~RnD+Administration',data=df1).fit().rsquared
Marketing_Spend=1/(1-Marketing_Spend)

df1={'Variables':['RnD','Administration','Marketing_Spend'],
    'VIF':[RnD,Administration,Marketing_Spend]}

df2=pd.DataFrame(df1)
df2
# Out:
#          Variables       VIF
# 0              RnD  2.468903
# 1   Administration  1.175091
# 2  Marketing_Spend  2.326773

# %%
# Residual Analysis

# %%
np.random.normal()
# Out:
# -0.7046526736388551

# %% [markdown]
# # Test for Normality of Residuals (Q-Q Plot)

# %%
import statsmodels.api as sm
QQplot=sm.qqplot(model.resid,line='q') 
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
residuals = model.resid
residuals
# Out:
# 0      -259.422890
# 1      2635.291768
# 2      8903.110904
# 3      9205.289974
# 4     -5951.574183
# 5     -6589.660571
# 6     -1991.586669
# 7     -4268.763048
# 8       470.070301
# 9     -5124.724110
# 10    10612.933633
# 11     8685.687039
# 12    12447.465818
# 13     6819.358337
# 14   -16945.996335
# 15   -16318.119985
# 16    10077.524599
# 17    -4822.077208
# 18    -4747.326806
# 19     7141.643633
# 20     1834.360769
# 21    -6006.431640
# 22    -4354.731717
# 23    -1262.625221
# 24    -4810.926113
# 25     5166.614935
# 26    -4867.035350
# 27    -9399.761457
# 28     1622.353995
# 29     -790.343452
# 30      485.217064
# 31     -204.296276
# 32    -1573.488985
# 33    -1136.087805
# 34     7673.526259
# 35     5967.910432
# 36    15422.015415
# 37      329.602292
# 38    11531.629352
# 39    -2723.251977
# 40     3423.956009
# 41     2996.273761
# 42      878.078179
# 43     9591.940037
# 44      588.975084
# 45    17275.430313
# 46    -6675.456853
# ...

# %%
sns.distplot(residuals)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
residuals.mean()
# Out:
# 7.625203579664231e-11

# %%
predictions = model.fittedvalues;
predictions
# Out:
# 0     192521.252890
# 1     189156.768232
# 2     182147.279096
# 3     173696.700026
# 4     172139.514183
# 5     163580.780571
# 6     158114.096669
# 7     160021.363048
# 8     151741.699699
# 9     154884.684110
# 10    135509.016367
# 11    135573.712961
# 12    129138.054182
# 13    127487.991663
# 14    149548.646335
# 15    146235.159985
# 16    116915.405401
# 17    130192.447208
# 18    129014.226806
# 19    115635.216367
# 20    116639.669231
# 21    117319.451640
# 22    114706.981717
# 23    109996.615221
# 24    113362.966113
# 25    102237.725065
# 26    110600.575350
# 27    114408.071457
# 28    101660.026005
# 29    101794.983452
# 30     99452.372936
# 31     97687.856276
# 32     99001.328985
# 33     97915.007805
# 34     89039.273741
# 35     90511.599568
# 36     75286.174585
# 37     89619.537708
# 38     69697.430648
# 39     83729.011977
# 40     74815.953991
# 41     74802.556239
# 42     70620.411821
# 43     60167.039963
# 44     64611.354916
# ...

# %%
df1.head(4)
# Out:
#          RnD  Administration  Marketing_Spend     Profit
# 0  165349.20       136897.80        471784.10  192261.83
# 1  162597.70       151377.59        443898.53  191792.06
# 2  153441.51       101145.55        407934.54  191050.39
# 3  144372.41       118671.85        383199.62  182901.99

# %%
pd.DataFrame({'Actual':df1.Profit,
             'Predicted':predictions,
             'Error':residuals})
# Out:
#        Actual      Predicted         Error
# 0   192261.83  192521.252890   -259.422890
# 1   191792.06  189156.768232   2635.291768
# 2   191050.39  182147.279096   8903.110904
# 3   182901.99  173696.700026   9205.289974
# 4   166187.94  172139.514183  -5951.574183
# 5   156991.12  163580.780571  -6589.660571
# 6   156122.51  158114.096669  -1991.586669
# 7   155752.60  160021.363048  -4268.763048
# 8   152211.77  151741.699699    470.070301
# 9   149759.96  154884.684110  -5124.724110
# 10  146121.95  135509.016367  10612.933633
# 11  144259.40  135573.712961   8685.687039
# 12  141585.52  129138.054182  12447.465818
# 13  134307.35  127487.991663   6819.358337
# 14  132602.65  149548.646335 -16945.996335
# 15  129917.04  146235.159985 -16318.119985
# 16  126992.93  116915.405401  10077.524599
# 17  125370.37  130192.447208  -4822.077208
# 18  124266.90  129014.226806  -4747.326806
# 19  122776.86  115635.216367   7141.643633
# 20  118474.03  116639.669231   1834.360769
# ...

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(predictions),
            get_standardized_values(residuals))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "RnD", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Administration", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Marketing_Spend", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Model Deletion Diagnostics
# # Detecting Influencers/Outliers
# # Cook's Distance

# %%
model_influence =model.get_influence()
(c, _)=model_influence.cooks_distance

# %%
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(df1)), np.round(c, 5))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c),np.max(c))
# Out:
# (49, 0.28808229275432634)

# %% [markdown]
# # High Influence points

# %%
from statsmodels.graphics.regressionplots import influence_plot 
influence_plot(model)
plt.show()

# %%
k = df1.shape[1] 
n = df1.shape[0] 

leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.30000000000000004

# %%
df1[df1.index.isin([49])]
# Out:
#     RnD  Administration  Marketing_Spend   Profit
# 49  0.0        116983.8         45173.06  14681.4

# %%
df1.iloc[[49],:]
# Out:
#     RnD  Administration  Marketing_Spend   Profit
# 49  0.0        116983.8         45173.06  14681.4

# %%
df1.head()
# Out:
#          RnD  Administration  Marketing_Spend     Profit
# 0  165349.20       136897.80        471784.10  192261.83
# 1  162597.70       151377.59        443898.53  191792.06
# 2  153441.51       101145.55        407934.54  191050.39
# 3  144372.41       118671.85        383199.62  182901.99
# 4  142107.34        91391.77        366168.42  166187.94

# %% [markdown]
# # Improving the model

# %%
df3=df1.drop(df1.index[[49]],axis=0).reset_index()
df3=df3.drop(['index'],axis=1)
df3
# Out:
#           RnD  Administration  Marketing_Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  101913.08       110594.11        229160.95  146121.95
# 11  100671.96        91790.61        249744.55  144259.40
# 12   93863.75       127320.38        249839.44  141585.52
# 13   91992.39       135495.07        252664.93  134307.35
# 14  119943.24       156547.42        256512.92  132602.65
# ...

# %%
model1=smf.ols('Profit~RnD+Administration+Marketing_Spend',data=df3).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     372.8
# Date:                Thu, 04 Aug 2022   Prob (F-statistic):           8.85e-32
# Time:                        20:30:35   Log-Likelihood:                -506.28
# No. Observations:                  49   AIC:                             1021.
# Df Residuals:                      45   BIC:                             1028.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
model1_influence = model1.get_influence()
(c1, _) = model1_influence.cooks_distance

# %%
fig = plt.subplots(figsize=(10, 7))
plt.stem(np.arange(len(df3)), np.round(c1, 5))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c1),np.max(c1))
# Out:
# (48, 0.39274420556321554)

# %%
influence_plot(model1)
plt.show()

# %%
df4=df3.drop(df1.index[[46,48]],axis=0).reset_index()
df4=df4.drop(['index'],axis=1)
df4
# Out:
#           RnD  Administration  Marketing_Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  101913.08       110594.11        229160.95  146121.95
# 11  100671.96        91790.61        249744.55  144259.40
# 12   93863.75       127320.38        249839.44  141585.52
# 13   91992.39       135495.07        252664.93  134307.35
# 14  119943.24       156547.42        256512.92  132602.65
# ...

# %%
model2=smf.ols('Profit~RnD+Administration+Marketing_Spend',data=df3).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     372.8
# Date:                Thu, 04 Aug 2022   Prob (F-statistic):           8.85e-32
# Time:                        20:30:39   Log-Likelihood:                -506.28
# No. Observations:                  49   AIC:                             1021.
# Df Residuals:                      45   BIC:                             1028.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
model2_influence = model2.get_influence()
(c2, _) = model2_influence.cooks_distance

# %%
(np.argmax(c2),np.max(c2))
# Out:
# (48, 0.39274420556321554)

# %% [markdown]
# # Prediction for new data

# %%
 new_data=pd.DataFrame({'RnD':14500,'Administration':11500,'Marketing_Spend':36000},index=[1])
model2.predict(new_data)
# Out:
# 1    64389.061162
# dtype: float64

# %%
model2.predict()
# Out:
# array([190716.67699881, 187537.12222744, 180575.52639649, 172461.14464179,
#        170863.48672087, 162582.58317676, 157741.3386332 , 159347.73531837,
#        151328.82694147, 154236.84677775, 135507.7926824 , 135472.85562054,
#        129355.59944933, 127780.12913907, 149295.40479556, 145937.94197463,
#        117437.62792078, 130408.62629498, 129129.23445693, 116641.00312136,
#        117097.73186633, 117911.0190379 , 115248.21779618, 110603.13904455,
#        114051.07387695, 103398.05438476, 111547.63893525, 114916.16502611,
#        103027.22943393, 103057.62176061, 100656.41022682,  99088.21369335,
#        100325.74133468,  98962.30313636,  90552.30780938,  91709.28867233,
#         77080.55425533,  90722.50324366,  71433.02195555,  85147.37564578,
#         76625.51030344,  76492.14517491,  72492.3949737 ,  62592.04971805,
#         67025.73110714,  50457.29720619,  58338.44362472,  49375.77665539,
#         51658.09681209])
